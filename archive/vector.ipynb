# %% [markdown]
# # Part 3: Query text chunk embeddings in a vector database
#
# This notebook illustrates how to query the text chunk embeddings which have been stored in `LanceDB`
#
# Based on a tutorial presented for GraphGeeks.org on 2024-08-14

# %%
import lancedb
import pandas as pd

LANCEDB_URI: str = "data/lancedb"

vect_db: lancedb.db.LanceDBConnection = lancedb.connect(LANCEDB_URI)
chunk_table: lancedb.table.LanceTable = vect_db.open_table("chunk")

# %%
query: str = "alzheimer"

# %%
df: pd.DataFrame = chunk_table.search(query).to_pandas()

df
# Out:
# /Users/paco/src/strwythura/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
#    uid                                                url  \
# 0    6  https://aaic.alz.org/releases-2024/processed-r...
# 1    2  https://aaic.alz.org/releases-2024/processed-r...
# 2    1  https://aaic.alz.org/releases-2024/processed-r...
# 3    9  https://www.theguardian.com/society/article/20...
# 4   12  https://www.theguardian.com/society/article/20...
# 5    5  https://aaic.alz.org/releases-2024/processed-r...
# 6    7  https://aaic.alz.org/releases-2024/processed-r...
# 7   11  https://www.theguardian.com/society/article/20...
# 8   13  https://www.theguardian.com/society/article/20...
# 9    3  https://aaic.alz.org/releases-2024/processed-r...
#
#                                                 text  \
# 0  It may affect the brain because it has high le...
# 1  However, there isn't a single food or ingredie...
# 2  The findings also suggest that people can decr...
# 3  US researchers say they have uncovered potenti...
# 4  "Processed red meat has also been shown to rai...
# 5  'Study results have been mixed on whether ther...
# 6  About the Alzheimer's Association Internationa...
# 7  The study also suggested that replacing one da...
# 8  However, he urged caution because the research...
# 9  They identified 11,173 dementia cases.\nThe re...
#
#                                               vector  _distance
# 0  [-0.2228194, 0.14646272, -0.17765053, 0.046882...  32.434887
# 1  [-0.30104715, 0.11894203, 0.019181741, 0.16478...  36.896915
# 2  [-0.15229337, 0.043053094, 0.13606068, 0.05749...  38.675430
# 3  [-0.18628058, 0.11941357, 0.03814063, 0.088553...  39.155540
# 4  [-0.10499327, 0.27258813, -0.094304204, 0.1779...  41.284718
# 5  [-0.14424151, 0.1776022, -0.05021852, 0.138240...  41.565147
# 6  [-0.5352495, 0.039061602, -0.10276959, -0.0100...  41.768105
# 7  [-0.17177889, 0.18276517, -0.034152847, 0.2259...  42.898357
# 8  [-0.12684007, 0.2953341, -0.040284596, 0.09349...  42.925724
# 9  [-0.34486166, 0.04708555, -0.06750553, -0.0837...  42.978661
